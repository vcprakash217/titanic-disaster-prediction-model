# %% [markdown]
# ## Download data files from kaggle website into data folder

# %%
import pandas as pd
import numpy as np
import os

# %%
raw_data_path = os.path.join(os.path.pardir, 'data', 'raw')
train_data_path = os.path.join(raw_data_path, 'train.csv')
test_data_path = os.path.join(raw_data_path, 'test.csv')

# %%
train_df = pd.read_csv(train_data_path, index_col='PassengerId')
test_df = pd.read_csv(test_data_path, index_col='PassengerId')

# %%
type(train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
train_df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
train_df.Name
# Out:
# PassengerId
# 1                                Braund, Mr. Owen Harris
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                 Heikkinen, Miss. Laina
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                               Allen, Mr. William Henry
# 6                                       Moran, Mr. James
# 7                                McCarthy, Mr. Timothy J
# 8                         Palsson, Master. Gosta Leonard
# 9      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                   Nasser, Mrs. Nicholas (Adele Achem)
# 11                       Sandstrom, Miss. Marguerite Rut
# 12                              Bonnell, Miss. Elizabeth
# 13                        Saundercock, Mr. William Henry
# 14                           Andersson, Mr. Anders Johan
# 15                  Vestrom, Miss. Hulda Amanda Adolfina
# 16                      Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
train_df[['Name', 'Age']]
# Out:
#                                                           Name   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3                                       Heikkinen, Miss. Laina  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                                     Allen, Mr. William Henry  35.0
# 6                                             Moran, Mr. James   NaN
# 7                                      McCarthy, Mr. Timothy J  54.0
# 8                               Palsson, Master. Gosta Leonard   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 11                             Sandstrom, Miss. Marguerite Rut   4.0
# 12                                    Bonnell, Miss. Elizabeth  58.0
# ...

# %%
# returns rows 6 to 10
train_df[5:10]
# Out:
#              Survived  Pclass  \
# PassengerId
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch  Ticket     Fare Cabin Embarked
# PassengerId
# 6                0      0  330877   8.4583   NaN        Q
# 7                0      0   17463  51.8625   E46        S
# 8                3      1  349909  21.0750   NaN        S
# ...

# %%
# returns passengerId (index) 5 to 10
train_df.loc[5:10,]
# Out:
#              Survived  Pclass  \
# PassengerId
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch  Ticket     Fare Cabin Embarked
# PassengerId
# 5                0      0  373450   8.0500   NaN        S
# ...

# %%
train_df.loc[5:10, 'Name':'Ticket']
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch  Ticket
# PassengerId
# 5                0      0  373450
# 6                0      0  330877
# 7                0      0   17463
# 8                3      1  349909
# 9                0      2  347742
# 10               1      0  237736

# %%
train_df.loc[5:10, ['Name','Ticket']]
# Out:
#                                                           Name  Ticket
# PassengerId
# 5                                     Allen, Mr. William Henry  373450
# 6                                             Moran, Mr. James  330877
# 7                                      McCarthy, Mr. Timothy J   17463
# 8                               Palsson, Master. Gosta Leonard  349909
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  347742
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  237736

# %%
male_passengers = train_df.loc[train_df.Sex == 'male']
print(len(male_passengers))
# Out:
# 577

# %% [markdown]
# ## Summary Statistics

# %%
train_df.describe()
train_df.describe(include='all')
# Out:
#           Survived      Pclass  \
# count   891.000000  891.000000
# unique         NaN         NaN
# top            NaN         NaN
# freq           NaN         NaN
# mean      0.383838    2.308642
# std       0.486592    0.836071
# min       0.000000    1.000000
# 25%       0.000000    2.000000
# 50%       0.000000    3.000000
# 75%       1.000000    3.000000
# max       1.000000    3.000000
#
#                                                     Name   Sex         Age  \
# count                                                891   891  714.000000
# unique                                               891     2         NaN
# top     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  male         NaN
# freq                                                   1   577         NaN
# mean                                                 NaN   NaN   29.699118
# std                                                  NaN   NaN   14.526497
# ...

# %%
#numerical features
#centrality measures - mean, median

print('Mean for Fare {0}'.format(train_df.Fare.mean()))
print('Median for Fare {0}'.format(train_df.Fare.median()))
print('Fare range {0}'.format(train_df.Fare.max() - train_df.Fare.min()))
print('25 percentile for Fare {0}'.format(train_df.Fare.quantile(.25)))
print('50 percentile for Fare {0}'.format(train_df.Fare.quantile(.50)))
print('75 percentile for Fare {0}'.format(train_df.Fare.quantile(.75)))
print('Variance for Fare {0}'.format(train_df.Fare.var()))
# square root of variance - used mainly to match the units as variance does square
print('Standard Deviation for Fare {0}'.format(train_df.Fare.std()))
# Out:
# Mean for Fare 32.204207968574636
# Median for Fare 14.4542
# Fare range 512.3292
# 25 percentile for Fare 7.9104
# 50 percentile for Fare 14.4542
# 75 percentile for Fare 31.0
# Variance for Fare 2469.436845743116
# Standard Deviation for Fare 49.6934285971809

# %%
# %matplotlib inline
train_df.Fare.plot(kind='box')

# %%
train_df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# gives proportions male/(male + female)
train_df.Sex.value_counts(normalize=True)
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
train_df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
train_df.Pclass.value_counts().plot(kind='bar')

# %%
# rot: rotates labels, adding ';' at the end removes the matplotlib object at the start
train_df.Pclass.value_counts().plot(kind='bar', rot=0, title='Class wise passenger counts', color='r')

# %%
train_df.Age.plot(kind='hist', title='Age Histogram', color='c')

# %%
train_df.Age.plot(kind='hist', title='Age Histogram', color='c', bins=20)

# %%
train_df.Age.plot(kind='kde', title='Age KDE plot', color='c')

# %%
train_df.Fare.plot(kind='hist', title='Fare Histogram', color='c', bins=20)

# %%
print('skewness for Age : {0:.2f}'.format(train_df.Age.skew()))
print('skewness for Fare : {0:.2f}'.format(train_df.Fare.skew()))
# Out:
# skewness for Age : 0.39
# skewness for Fare : 4.79

# %%
train_df.plot.scatter(x='Age', y='Fare', title='Scatter Plot: Age vs Fare')

# %%
train_df.plot.scatter(x='Age', y='Fare', title='Scatter Plot: Age vs Fare', alpha=0.1)

# %%
train_df.plot.scatter(x='Pclass', y='Fare', title='Scatter Plot: PClass vs Fare', alpha=0.15)

# %%
train_df.groupby(['Sex']).Age.median()
# Out:
# Sex
# female    27.0
# male      29.0
# Name: Age, dtype: float64

# %%
train_df.groupby(['Pclass']).Fare.median()
# Out:
# Pclass
# 1    60.2875
# 2    14.2500
# 3     8.0500
# Name: Fare, dtype: float64

# %%
train_df.groupby(['Pclass']).Age.median()
# Out:
# Pclass
# 1    37.0
# 2    29.0
# 3    24.0
# Name: Age, dtype: float64

# %%
train_df.groupby(['Pclass'])['Age', 'Fare'].median()
# Out:
#          Age     Fare
# Pclass
# 1       37.0  60.2875
# 2       29.0  14.2500
# 3       24.0   8.0500

# %%
train_df.groupby(['Pclass']).agg({'Fare':'mean', 'Age':'median'})
# Out:
#              Fare   Age
# Pclass
# 1       84.154687  37.0
# 2       20.662183  29.0
# 3       13.675550  24.0

# %%
# numpy can also be used
aggregations = {
    'Fare': {
        'mean_fare': 'mean',
        'median_fare': 'median',
        'min_fare': min,
        'max_fare': np.max
    },
    'Age': {
        'mean_age': 'mean',
        'median_age': 'median',
        'min_age': min,
        'max_age': max  
    }
}
train_df.groupby(['Pclass']).agg(aggregations)
# Out:
# /Users/pv032381/anaconda3/envs/MachineLearning-1/lib/python3.6/site-packages/pandas/core/groupby/groupby.py:4656: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#              Fare                                       Age             \
#         mean_fare median_fare min_fare  max_fare   mean_age median_age
# Pclass
# 1       84.154687     60.2875      0.0  512.3292  38.233441       37.0
# 2       20.662183     14.2500      0.0   73.5000  29.877630       29.0
# 3       13.675550      8.0500      0.0   69.5500  25.140620       24.0
#
#
#        min_age max_age
# Pclass
# 1         0.92    80.0
# 2         0.67    70.0
# 3         0.42    74.0

# %%
train_df.groupby(['Pclass', 'Embarked']).Fare.median()
# Out:
# Pclass  Embarked
# 1       C           78.2667
#         Q           90.0000
#         S           52.0000
# 2       C           24.0000
#         Q           12.3500
#         S           13.5000
# 3       C            7.8958
#         Q            7.7500
#         S            8.0500
# Name: Fare, dtype: float64

# %%
pd.crosstab(train_df.Sex, train_df.Pclass)
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %%
pd.crosstab(train_df.Sex, train_df.Pclass).plot(kind='bar')

# %%
train_df.pivot_table(index='Sex', columns='Pclass', values='Age', aggfunc='mean')
# Out:
# Pclass          1          2          3
# Sex
# female  34.611765  28.722973  21.750000
# male    41.281386  30.740707  26.507589

# %%
# Result similar to above pivot table
train_df.groupby(['Sex','Pclass']).Age.mean()
# Out:
# Sex     Pclass
# female  1         34.611765
#         2         28.722973
#         3         21.750000
# male    1         41.281386
#         2         30.740707
#         3         26.507589
# Name: Age, dtype: float64

# %%
train_df.groupby(['Sex','Pclass']).Age.mean().unstack()
# Out:
# Pclass          1          2          3
# Sex
# female  34.611765  28.722973  21.750000
# male    41.281386  30.740707  26.507589

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 123.5+ KB

# %%
train_df[train_df.Embarked.isnull()]
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 62                  1       1                        Icard, Miss. Amelie
# 830                 1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#                 Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# PassengerId
# 62           female  38.0      0      0  113572  80.0   B28      NaN
# 830          female  62.0      0      0  113572  80.0   B28      NaN

# %%
train_df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train_df.Survived
# Out:
# PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
# 6      0
# 7      0
# 8      0
# 9      1
# 10     1
# 11     1
# 12     1
# 13     0
# 14     0
# 15     0
# 16     1
# 17     0
# 18     1
# 19     0
# 20     1
# 21     0
# 22     1
# 23     1
# 24     1
# 25     0
# 26     1
# 27     0
# 28     0
# 29     1
# 30     0
#       ..
# 862    0
# 863    1
# 864    0
# 865    0
# 866    1
# 867    1
# 868    0
# 869    0
# 870    1
# 871    0
# 872    1
# 873    0
# 874    0
# 875    1
# 876    1
# 877    0
# 878    0
# 879    0
# 880    1
# 881    1
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64

# %%
pd.crosstab(train_df.Embarked, train_df.Survived)
# Out:
# Survived    0    1
# Embarked
# C          75   93
# Q          47   30
# S         427  217

# %%
# Since Fare for both the missing Embarked rows is 80, we'll find out median fares for different Embarked points
train_df.groupby(['Pclass', 'Embarked']).Fare.median()
# Out:
# Pclass  Embarked
# 1       C           78.2667
#         Q           90.0000
#         S           52.0000
# 2       C           24.0000
#         Q           12.3500
#         S           13.5000
# 3       C            7.8958
#         Q            7.7500
#         S            8.0500
# Name: Fare, dtype: float64

# %%
# Since Embark point C has fare closest to 80 we'll replace missing Embarked rows with C
train_df.Embarked.fillna('C', inplace=True)

# %%
train_df[train_df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
test_df[test_df.Fare.isnull()]
# Out:
#              Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# PassengerId
# 1044              3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#              Fare Cabin Embarked
# PassengerId
# 1044          NaN   NaN        S

# %%
train_df.Fare
# Out:
# PassengerId
# 1        7.2500
# 2       71.2833
# 3        7.9250
# 4       53.1000
# 5        8.0500
# 6        8.4583
# 7       51.8625
# 8       21.0750
# 9       11.1333
# 10      30.0708
# 11      16.7000
# 12      26.5500
# 13       8.0500
# 14      31.2750
# 15       7.8542
# 16      16.0000
# 17      29.1250
# 18      13.0000
# 19      18.0000
# 20       7.2250
# 21      26.0000
# 22      13.0000
# 23       8.0292
# 24      35.5000
# 25      21.0750
# 26      31.3875
# 27       7.2250
# 28     263.0000
# 29       7.8792
# 30       7.8958
#          ...
# 862     11.5000
# 863     25.9292
# 864     69.5500
# 865     13.0000
# 866     13.0000
# 867     13.8583
# 868     50.4958
# 869      9.5000
# 870     11.1333
# 871      7.8958
# 872     52.5542
# 873      5.0000
# 874      9.0000
# 875     24.0000
# 876      7.2250
# 877      9.8458
# 878      7.8958
# 879      7.8958
# 880     83.1583
# 881     26.0000
# 882      7.8958
# 883     10.5167
# 884     10.5000
# ...

# %%
median_fare = train_df.loc[(train_df.Pclass == 3) & (train_df.Embarked == 'S')].Fare.median()

# %%
test_df.Fare.fillna(median_fare, inplace=True)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    891 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 123.5+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
# Pclass      418 non-null int64
# Name        418 non-null object
# Sex         418 non-null object
# Age         332 non-null float64
# SibSp       418 non-null int64
# Parch       418 non-null int64
# Ticket      418 non-null object
# Fare        418 non-null float64
# Cabin       91 non-null object
# Embarked    418 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %%
train_df[train_df.Age.isnull()]
# Out:
#              Survived  Pclass                                            Name  \
# PassengerId
# 6                   0       3                                Moran, Mr. James
# 18                  1       2                    Williams, Mr. Charles Eugene
# 20                  1       3                         Masselmani, Mrs. Fatima
# 27                  0       3                         Emir, Mr. Farred Chehab
# 29                  1       3                   O'Dwyer, Miss. Ellen "Nellie"
# 30                  0       3                             Todoroff, Mr. Lalio
# 32                  1       1  Spencer, Mrs. William Augustus (Marie Eugenie)
# 33                  1       3                        Glynn, Miss. Mary Agatha
# 37                  1       3                                Mamee, Mr. Hanna
# 43                  0       3                             Kraeff, Mr. Theodor
# 46                  0       3                        Rogers, Mr. William John
# ...

# %%
test_df[test_df.Age.isnull()]
# Out:
#              Pclass                                               Name  \
# PassengerId
# 902               3                                   Ilieff, Mr. Ylio
# 914               1               Flegenheim, Mrs. Alfred (Antoinette)
# 921               3                                  Samaan, Mr. Elias
# 925               3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 928               3                                Roth, Miss. Sarah A
# 931               3                                      Hee, Mr. Ling
# 933               1                        Franklin, Mr. Thomas Parham
# 939               3                           Shaughnessy, Mr. Patrick
# 946               2                  Mangiavacchi, Mr. Serafino Emilio
# 950               3                          Davison, Mr. Thomas Henry
# 957               2  Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...
# 968               3                                   Miles, Mr. Frank
# ...

# %%
train_df.Age.plot(kind='hist', bins=20)

# %%
# option 1 - but there are some outliers in 70, 80
train_df.Age.mean()
# Out:
# 29.69911764705882

# %%
# option 2
train_df.groupby('Sex').Age.median()
# Out:
# Sex
# female    27.0
# male      29.0
# Name: Age, dtype: float64

# %%
train_df[train_df.Age.notnull()].boxplot('Age', 'Sex')

# %%
train_df[train_df.Age.notnull()].boxplot('Age', 'Pclass')

# %%
train_df.Name
# Out:
# PassengerId
# 1                                Braund, Mr. Owen Harris
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                 Heikkinen, Miss. Laina
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                               Allen, Mr. William Henry
# 6                                       Moran, Mr. James
# 7                                McCarthy, Mr. Timothy J
# 8                         Palsson, Master. Gosta Leonard
# 9      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                   Nasser, Mrs. Nicholas (Adele Achem)
# 11                       Sandstrom, Miss. Marguerite Rut
# 12                              Bonnell, Miss. Elizabeth
# 13                        Saundercock, Mr. William Henry
# 14                           Andersson, Mr. Anders Johan
# 15                  Vestrom, Miss. Hulda Amanda Adolfina
# 16                      Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
def getTitle(name):
    first_name_with_title = name.split(',')[1]
    title = first_name_with_title.split('.')[0]
    title = title.strip().lower()
    return title

# %%
train_df.Name.map(lambda x : getTitle(x))
# Out:
# PassengerId
# 1          mr
# 2         mrs
# 3        miss
# 4         mrs
# 5          mr
# 6          mr
# 7          mr
# 8      master
# 9         mrs
# 10        mrs
# 11       miss
# 12       miss
# 13         mr
# 14         mr
# 15       miss
# 16        mrs
# 17     master
# 18         mr
# 19        mrs
# 20        mrs
# 21         mr
# 22         mr
# 23       miss
# 24         mr
# 25       miss
# 26        mrs
# 27         mr
# 28         mr
# 29       miss
# 30         mr
#         ...
# 862        mr
# 863       mrs
# 864      miss
# 865        mr
# 866       mrs
# 867      miss
# 868        mr
# 869        mr
# 870    master
# 871        mr
# 872       mrs
# 873        mr
# 874        mr
# 875       mrs
# 876      miss
# 877        mr
# 878        mr
# 879        mr
# 880       mrs
# 881       mrs
# 882        mr
# 883      miss
# 884        mr
# 885        mr
# 886       mrs
# 887       rev
# 888      miss
# 889      miss
# 890        mr
# 891        mr
# ...

# %%
train_df.Name.map(lambda x : getTitle(x)).unique()
# Out:
# array(['mr', 'mrs', 'miss', 'master', 'don', 'rev', 'dr', 'mme', 'ms',
#        'major', 'lady', 'sir', 'mlle', 'col', 'capt', 'the countess',
#        'jonkheer'], dtype=object)

# %%
def getTitle(name):
    title_group = {
        'mr': 'Mr',
        'mrs': 'Mrs',
        'miss': 'Miss',
        'master': 'Master',
        'don': 'Sir',
        'rev': 'Sir',
        'dr': 'Officer',
        'mme': 'Mrs',
        'ms': 'Mrs',
        'major': 'Officer',
        'lady': 'Lady',
        'sir': 'Sir',
        'mlle': 'Miss',
        'col': 'Officer',
        'capt': 'Officer',
        'the countess': 'Lady',
        'jonkheer': 'Sir',
        'dona': 'Lady'
        
    }
    first_name_with_title = name.split(',')[1]
    title = first_name_with_title.split('.')[0]
    title = title.strip().lower()
    return title_group[title]

# %%
train_df['Title'] = train_df.Name.map(lambda x : getTitle(x))

# %%
train_df.head
# Out:
# <bound method NDFrame.head of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# ...

# %%
test_df['Title'] = test_df.Name.map(lambda x : getTitle(x))

# %%
train_df[train_df.Age.notnull()].boxplot('Age', 'Title')

# %%
test_df[test_df.Age.notnull()].boxplot('Age', 'Title')

# %%
title_age_median = train_df.groupby('Title').Age.transform('median')
train_df.Age.fillna(title_age_median, inplace=True)

# %%
title_age_median_test = test_df.groupby('Title').Age.transform('median')
test_df.Age.fillna(title_age_median_test, inplace=True)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 11 columns):
# Pclass      418 non-null int64
# Name        418 non-null object
# Sex         418 non-null object
# Age         418 non-null float64
# SibSp       418 non-null int64
# Parch       418 non-null int64
# Ticket      418 non-null object
# Fare        418 non-null float64
# Cabin       91 non-null object
# Embarked    418 non-null object
# Title       418 non-null object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 39.2+ KB

# %% [markdown]
# ## Outliers

# %%
train_df.Age.plot(kind='hist', bins=20, title='Age histogram')

# %%
train_df.loc[train_df.Age > 70]
# Out:
#              Survived  Pclass                                  Name   Sex  \
# PassengerId
# 97                  0       1             Goldschmidt, Mr. George B  male
# 117                 0       3                  Connors, Mr. Patrick  male
# 494                 0       1               Artagaveytia, Mr. Ramon  male
# 631                 1       1  Barkworth, Mr. Algernon Henry Wilson  male
# 852                 0       3                   Svensson, Mr. Johan  male
#
#               Age  SibSp  Parch    Ticket     Fare Cabin Embarked Title
# PassengerId
# 97           71.0      0      0  PC 17754  34.6542    A5        C    Mr
# 117          70.5      0      0    370369   7.7500   NaN        Q    Mr
# 494          71.0      0      0  PC 17609  49.5042   NaN        C    Mr
# 631          80.0      0      0     27042  30.0000   A23        S    Mr
# 852          74.0      0      0    347060   7.7750   NaN        S    Mr

# %%
train_df.Fare.plot(kind='hist', title='Fare histogram', bins=20)

# %%
train_df.Fare.plot(kind='box')

# %%
train_df.loc[train_df.Fare == train_df.Fare.max()]
# Out:
#              Survived  Pclass                                Name     Sex  \
# PassengerId
# 259                 1       1                    Ward, Miss. Anna  female
# 680                 1       1  Cardeza, Mr. Thomas Drake Martinez    male
# 738                 1       1              Lesurer, Mr. Gustave J    male
#
#               Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# PassengerId
# 259          35.0      0      0  PC 17755  512.3292          NaN        C
# 680          36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 738          35.0      0      0  PC 17755  512.3292         B101        C
#
#             Title
# PassengerId
# 259          Miss
# 680            Mr
# 738            Mr

# %%
pd.qcut(train_df.Fare, 4, labels=['very_low', 'low', 'high', 'very_high'])
# Out:
# PassengerId
# 1       very_low
# 2      very_high
# 3            low
# 4      very_high
# 5            low
# 6            low
# 7      very_high
# 8           high
# 9            low
# 10          high
# 11          high
# 12          high
# 13           low
# 14     very_high
# 15      very_low
# 16          high
# 17          high
# 18           low
# 19          high
# 20      very_low
# 21          high
# 22           low
# 23           low
# 24     very_high
# 25          high
# 26     very_high
# 27      very_low
# 28     very_high
# 29      very_low
# 30      very_low
#          ...
# 862          low
# 863         high
# 864    very_high
# 865          low
# 866          low
# 867          low
# 868    very_high
# 869          low
# 870          low
# 871     very_low
# 872    very_high
# 873     very_low
# 874          low
# 875         high
# 876     very_low
# 877          low
# 878     very_low
# 879     very_low
# 880    very_high
# 881         high
# 882     very_low
# ...

# %%
pd.qcut(train_df.Fare, 4, labels=['very_low', 'low', 'high', 'very_high']).value_counts().plot(kind='bar', rot=0)

# %%
train_df['Fare_Bin'] = pd.qcut(train_df.Fare, 4, labels=['very_low', 'low', 'high', 'very_high'])

# %%
test_df['Fare_Bin'] = pd.qcut(test_df.Fare, 4, labels=['very_low', 'low', 'high', 'very_high'])

# %% [markdown]
# ## Feature Engineering

# %%
# Age
train_df['AgeState'] = np.where(train_df.Age >=18, 'Adult', 'Child')

# %%
train_df['AgeState'].value_counts()
# Out:
# Adult    774
# Child    117
# Name: AgeState, dtype: int64

# %%
test_df['AgeState'] = np.where(test_df.Age >=18, 'Adult', 'Child')

# %%
pd.crosstab(train_df.Survived, train_df.AgeState)
# Out:
# AgeState  Adult  Child
# Survived
# 0           495     54
# 1           279     63

# %%
# Family size
train_df['FamilySize'] = train_df.Parch + train_df.SibSp + 1 # 1 for self

# %%
test_df['FamilySize'] = test_df.Parch + test_df.SibSp + 1 # 1 for self

# %%
train_df['FamilySize'].plot(kind='hist')

# %%
pd.crosstab(train_df.Survived, train_df.FamilySize)
# Out:
# FamilySize   1   2   3   4   5   6   7   8   11
# Survived
# 0           374  72  43   8  12  19   8   6   7
# 1           163  89  59  21   3   3   4   0   0

# %%
# Motherhood
train_df['IsMother'] = np.where(((train_df.Sex=='female') & (train_df.Age > 18) & (train_df.Parch > 0) & (train_df.Title != 'Miss')), 1, 0)

# %%
test_df['IsMother'] = np.where(((test_df.Sex=='female') & (test_df.Age > 18) & (test_df.Parch > 0) & (test_df.Title != 'Miss')), 1, 0)

# %%
pd.crosstab(train_df.Survived, train_df.IsMother)
# Out:
# IsMother    0   1
# Survived
# 0         533  16
# 1         303  39

# %%
train_df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
train_df.loc[train_df.Cabin == 'T', 'Cabin'] = np.NaN

# %%
test_df.loc[test_df.Cabin == 'T', 'Cabin'] = np.NaN

# %%
def getDeck(cabin):
    return np.where(pd.notnull(cabin), str(cabin)[0].upper(), 'Z') # replace NaN with deck Z

# %%
train_df['Deck'] = train_df['Cabin'].map(lambda x : getDeck(x))

# %%
test_df['Deck'] = test_df['Cabin'].map(lambda x : getDeck(x))

# %%
train_df.Deck.value_counts()
# Out:
# Z    688
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# Name: Deck, dtype: int64

# %%
pd.crosstab(train_df.Survived, train_df.Deck)
# Out:
# Deck      A   B   C   D   E  F  G    Z
# Survived
# 0         8  12  24   8   8  5  2  482
# 1         7  35  35  25  24  8  2  206

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 17 columns):
# Survived      891 non-null int64
# Pclass        891 non-null int64
# Name          891 non-null object
# Sex           891 non-null object
# Age           891 non-null float64
# SibSp         891 non-null int64
# Parch         891 non-null int64
# Ticket        891 non-null object
# Fare          891 non-null float64
# Cabin         203 non-null object
# Embarked      891 non-null object
# Title         891 non-null object
# Fare_Bin      891 non-null category
# AgeState      891 non-null object
# FamilySize    891 non-null int64
# IsMother      891 non-null int64
# Deck          891 non-null object
# dtypes: category(1), float64(2), int64(6), object(8)
# memory usage: 159.4+ KB

# %% [markdown]
# ## Categorical feature encoding

# %%
train_df['IsMale'] = np.where(train_df['Sex'] == 'male', 1, 0)

# %%
test_df['IsMale'] = np.where(test_df['Sex'] == 'male', 1, 0)

# %%
train_df = pd.get_dummies(train_df, columns=['Deck', 'Pclass', 'Fare_Bin', 'Embarked', 'AgeState'])

# %%
test_df = pd.get_dummies(test_df, columns=['Deck', 'Pclass', 'Fare_Bin', 'Embarked', 'AgeState'])

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 33 columns):
# Survived              891 non-null int64
# Name                  891 non-null object
# Sex                   891 non-null object
# Age                   891 non-null float64
# SibSp                 891 non-null int64
# Parch                 891 non-null int64
# Ticket                891 non-null object
# Fare                  891 non-null float64
# Cabin                 203 non-null object
# Title                 891 non-null object
# FamilySize            891 non-null int64
# IsMother              891 non-null int64
# IsMale                891 non-null int64
# Deck_A                891 non-null uint8
# Deck_B                891 non-null uint8
# Deck_C                891 non-null uint8
# Deck_D                891 non-null uint8
# Deck_E                891 non-null uint8
# Deck_F                891 non-null uint8
# Deck_G                891 non-null uint8
# ...

# %% [markdown]
# ## Drop and reorder columns

# %%
train_df.head()
# Out:
#              Survived                                               Name  \
# PassengerId
# 1                   0                            Braund, Mr. Owen Harris
# 2                   1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                   1                             Heikkinen, Miss. Laina
# 4                   1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0                           Allen, Mr. William Henry
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 2            female  38.0      1      0          PC 17599  71.2833   C85
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
#
# ...

# %%
train_df.drop(['Cabin', 'Name', 'Ticket', 'Parch', 'SibSp', 'Sex'], axis=1, inplace=True)

# %%
test_df.drop(['Cabin', 'Name', 'Ticket', 'Parch', 'SibSp', 'Sex'], axis=1, inplace=True)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 27 columns):
# Survived              891 non-null int64
# Age                   891 non-null float64
# Fare                  891 non-null float64
# Title                 891 non-null object
# FamilySize            891 non-null int64
# IsMother              891 non-null int64
# IsMale                891 non-null int64
# Deck_A                891 non-null uint8
# Deck_B                891 non-null uint8
# Deck_C                891 non-null uint8
# Deck_D                891 non-null uint8
# Deck_E                891 non-null uint8
# Deck_F                891 non-null uint8
# Deck_G                891 non-null uint8
# Deck_Z                891 non-null uint8
# Pclass_1              891 non-null uint8
# Pclass_2              891 non-null uint8
# Pclass_3              891 non-null uint8
# Fare_Bin_very_low     891 non-null uint8
# Fare_Bin_low          891 non-null uint8
# ...

# %%
# reorder columns
columns = [column for column in train_df.columns if column!='Survived']
columns = ['Survived'] + columns
train_df = train_df[columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 27 columns):
# Survived              891 non-null int64
# Age                   891 non-null float64
# Fare                  891 non-null float64
# Title                 891 non-null object
# FamilySize            891 non-null int64
# IsMother              891 non-null int64
# IsMale                891 non-null int64
# Deck_A                891 non-null uint8
# Deck_B                891 non-null uint8
# Deck_C                891 non-null uint8
# Deck_D                891 non-null uint8
# Deck_E                891 non-null uint8
# Deck_F                891 non-null uint8
# Deck_G                891 non-null uint8
# Deck_Z                891 non-null uint8
# Pclass_1              891 non-null uint8
# Pclass_2              891 non-null uint8
# Pclass_3              891 non-null uint8
# Fare_Bin_very_low     891 non-null uint8
# Fare_Bin_low          891 non-null uint8
# ...

# %% [markdown]
# ## Save processed data set

# %%
processed_data_path = os.path.join(os.path.pardir, 'data', 'processed')
train_data_path = os.path.join(processed_data_path, 'train.csv')
test_data_path = os.path.join(processed_data_path, 'test.csv')

# %%
train_df.to_csv(train_data_path)
test_df.to_csv(test_data_path)

# %% [markdown]
# ## Data processing script

# %%
get_processed_data_script = os.path.join(os.path.pardir, 'src', 'data', 'get_processed_data.py')

# %%
# %%writefile $get_processed_data_script
# import numpy as np
# import pandas as pd
# import os
#
# def read_data():
#     # set raw data paths
#     raw_data_path = os.path.join(os.path.pardir, 'data', 'raw')
#     train_file_path = os.path.join(raw_data_path, 'train.csv')
#     test_file_path = os.path.join(raw_data_path, 'test.csv')
#     # read data
#     train_df = pd.read_csv(train_file_path, index_col='PassengerId')
#     test_df = pd.read_csv(test_file_path, index_col='PassengerId')
#     test_df['Survived'] = -888
#     df = pd.concat((train_df, test_df), axis=0)
#     return df
#
# def process_data(df):
#     # method chaining concept
#     return(df
#            # create title attribute
#            .assign(Title = lambda x : x.Name.map(getTitle))
#            # missing values
#            .pipe(fill_missing_values)
#            # create fare bin feature
#            .assign(Fare_Bin = lambda x : pd.qcut(x.Fare, 4, labels=['very_low', 'low', 'high', 'very_high']))
#            # create age state
#            .assign(AgeState = lambda x : np.where(x.Age>18, 'Adult', 'Child'))
#            # create family size
#            .assign(FamilySize = lambda x : x.Parch + x.SibSp + 1)
#            # create isMother
#            .assign(IsMother = lambda x : np.where(((x.Sex=='female') & (x.Age > 18) & (x.Parch > 0) & (x.Title != 'Miss')), 1, 0))
#            # replace Cabin 'T' with nan
#            .assign(Cabin = lambda x : np.where(x.Cabin=='T', np.nan, x.Cabin))
#            # create deck
#            .assign(Deck = lambda x : x.Cabin.map(getDeck))
#            # feature encoding
#            .assign(IsMale = lambda x : np.where(x.Sex=='male', 1, 0))
#            .pipe(pd.get_dummies, columns=['Deck', 'Pclass', 'Title', 'Fare_Bin', 'Embarked', 'AgeState'])
#            # drop unused columns
#            .drop(columns=['Cabin', 'Name', 'Ticket', 'Parch', 'SibSp', 'Sex'], axis=1)
#            #reorder columns
#            .pipe(reorderColumns)
#           )
#
# def getTitle(name):
#     title_group = {
#         'mr': 'Mr',
#         'mrs': 'Mrs',
#         'miss': 'Miss',
#         'master': 'Master',
#         'don': 'Sir',
#         'rev': 'Sir',
#         'dr': 'Officer',
#         'mme': 'Mrs',
#         'ms': 'Mrs',
#         'major': 'Officer',
#         'lady': 'Lady',
#         'sir': 'Sir',
#         'mlle': 'Miss',
#         'col': 'Officer',
#         'capt': 'Officer',
#         'the countess': 'Lady',
#         'jonkheer': 'Sir',
#         'dona': 'Lady'
#
#     }
#     first_name_with_title = name.split(',')[1]
#     title = first_name_with_title.split('.')[0]
#     title = title.strip().lower()
#     return title_group[title]
#
# def getDeck(cabin):
#     return np.where(pd.notnull(cabin), str(cabin)[0].upper(), 'Z') # replace NaN with deck Z
#
# def fill_missing_values(df):
#     # Embarked
#     df.Embarked.fillna('C', inplace=True)
#     # Fare
#     median_fare = df[(df.Pclass == 3) & (df.Embarked == 'S')].Fare.median()
#     df.Fare.fillna(median_fare, inplace=True)
#     # Age
#     title_age_median = df.groupby('Title').Age.transform('median')
#     df.Age.fillna(title_age_median, inplace=True)
#     return df
#
# def reorderColumns(df):
#     columns = [column for column in df.columns if column != 'Survived']
#     columns = ['Survived'] + columns
#     df = df[columns]
#     return df
#
# def write_data(df):
#     processed_data_path = os.path.join(os.path.pardir, 'data', 'processed')
#     train_data_path = os.path.join(processed_data_path, 'train.csv')
#     test_data_path = os.path.join(processed_data_path, 'test.csv')
#     # train data
#     df[df.Survived != -888].to_csv(train_data_path)
#     # test data
#     # remove Survived column for test data
#     columns = columns.remove('Survived')
#     df[df.Survived == -888][columns].to_csv(test_data_path)
#
#
# if __name__ == '__main__':
#     df = read_data()
#     df = process_data(df)
#     write_data(df)
# Out:
# Overwriting ../src/data/get_processed_data.py

# %% [markdown]
# ## Advanced visualizations using Matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(train_df.Age)
# Out:
# (array([ 58.,  46., 213., 288., 135.,  70.,  46.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(train_df.Age, bins=20, color='c')
plt.title('Age Histogram')
plt.xlabel('Bins')
plt.ylabel('Count')
plt.show()

# %%
f, ax = plt.subplots()
ax.hist(train_df.Age, bins=20, color='c')
ax.set_title('Age Histogram')
ax.set_xlabel('Bins')
ax.set_ylabel('Count')
plt.show()

# %%
f, (ax1,ax2) = plt.subplots(1, 2, figsize=(14,3))

ax1.hist(train_df.Fare, bins=20, color='c')
ax1.set_title('Fare Histogram')
ax1.set_xlabel('Bins')
ax1.set_ylabel('Count')

ax2.hist(train_df.Age, bins=20, color='tomato')
ax2.set_title('Age Histogram')
ax2.set_xlabel('Bins')
ax2.set_ylabel('Count')

plt.show()

# %%
f, ax_array = plt.subplots(3, 2, figsize=(14,7))

ax_array[0,0].hist(train_df.Fare, bins=20, color='c')
ax_array[0,0].set_title('Fare Histogram')
ax_array[0,0].set_xlabel('Bins')
ax_array[0,0].set_ylabel('Count')

ax_array[0,1].hist(train_df.Age, bins=20, color='tomato')
ax_array[0,1].set_title('Age Histogram')
ax_array[0,1].set_xlabel('Bins')
ax_array[0,1].set_ylabel('Count')

ax_array[1,0].boxplot(train_df.Fare.values)
ax_array[1,0].set_title('Fare Boxplot')
ax_array[1,0].set_xlabel('Bins')
ax_array[1,0].set_ylabel('Count')

ax_array[1,1].boxplot(train_df.Age.values)
ax_array[1,1].set_title('Age Boxplot')
ax_array[1,1].set_xlabel('Bins')
ax_array[1,1].set_ylabel('Count')

ax_array[2,0].scatter(train_df.Age, train_df.Fare, alpha=0.15)
ax_array[2,0].set_title('Fare Scatter plot')
ax_array[2,0].set_xlabel('Bins')
ax_array[2,0].set_ylabel('Count')

# Does
ax_array[2,1].axis('off')

# Adds padding to each subplot
plt.tight_layout()

plt.show()
